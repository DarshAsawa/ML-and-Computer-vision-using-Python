# %%
from PIL import Image

# %%
pug = Image.open('pug.jpg')

# %%
pug.resize((200,200))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x23569843D88>

# %%
#open image in a new window
pug.show()

# %%
#rotate image 
#using pug.rotate(45) cuts some parts of image.
pug.rotate(45,expand=True)
# Out:
# <PIL.Image.Image image mode=RGB size=720x720 at 0x2356AEC3E48>

# %%
type(pug)
# Out:
# PIL.JpegImagePlugin.JpegImageFile
